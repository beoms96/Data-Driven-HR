# %% [markdown]
# # Import Libraries
# #### Standard

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# #### Visualization

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import colors
from matplotlib import rc
import seaborn as sns
import networkx as nx

# %% [markdown]
# # Import Data
# Data Preprocessing 단계에서 생성된 통합 데이터 테이블을 불러온다

# %%
root = os.path.join(os.getcwd(), 'DATA')

df_raw = pd.read_csv(os.path.join(root, 'raw_data.csv'), index_col = 0)
df_project = pd.read_csv(os.path.join(root, 'project_data.csv'), index_col = 0)

code_jeom = pd.read_csv(os.path.join(root, 'jeom_code.csv'), index_col = 0)
code_jikwhi = pd.read_csv(os.path.join(root, 'jikwhi_code.csv'), index_col = 0)
code_jkmu = pd.read_csv(os.path.join(root, 'jkmu_code.csv'), index_col = 0)

# %% [markdown]
# 직원 데이터는 지속적으로 참고해야 한다

# %%
df_jikwon = pd.read_csv(os.path.join(root, 'jikwon.csv'), encoding='cp949')

# %% [markdown]
# ----

# %% [markdown]
# # Drop Data

# %% [markdown]
# 요청구분은 무수정, 수정, 신규, 폐기, 총 4종류가 있는데 우리는 신규/수정한 이력만을 볼 것이다
# 이를 통해 프로그램을 신규/수정한 이력이 없는 직원들도 제거된다

# %%
df_raw[['요청구분', '요청번호']].groupby('요청구분').count()
# Out:
#         요청번호
# 요청구분
# 무수정     5557
# 수정    189113
# 신규    166315
# 폐기      8934

# %%
print(df_raw.shape, end="->")
df = df_raw[(df_raw['요청구분'] == '신규') | (df_raw['요청구분'] == '수정')]
print(df.shape)
# Out:
# (370040, 23)->(355428, 23)

# %%
df['요청구분'].unique()
# Out:
# array(['수정', '신규'], dtype=object)

# %% [markdown]
# # 분류하기

# %% [markdown]
# ### 프로그램종류
# 프로그램 종류를 파악해서 어떤 언어/툴 등을 사용했는지 파악 가능

# %%
df[['프로그램종류']].drop_duplicates().reset_index(drop=True)
# Out:
#              프로그램종류
# 0            온라인서비스
# 1          채널화면_txt
# 2                배치
# 3              거래코드
# 4          채널화면_MAP
# 5          IO포맷 ALL
# 6          DBIO MAP
# 7              DBIO
# 8              공통모듈
# 9          채널화면_mrd
# 10            채널매핑룰
# 11            웹_JSP
# 12             연동코드
# 13            SHELL
# 14             상주배치
# 15             IO포맷
# 16      Header FILE
# 17              XML
# 18             Java
# 19        HTML5_xml
# 20           MODULE
# 21         배치(*.pc)
# 22       HTML5_스크립트
# 23    FLEX(/bin 파일)
# 24           SCRIPT
# 25    FLEX(/src 파일)
# 26      프로프레임소스(.c)
# 27     웹_비지니스(.xml)
# 28       웹_서식(.xml)
# 29            Image
# ..              ...
# 41        .net(dll)
# 42            화면_VB
# 43              CTL
# 44            2PC배치
# 45       채널매핑룰.rule
# 46        채널매핑룰.chl
# 47        HTML5_이미지
# 48         웹_기타(IT)
# 49            후행성배치
# 50          GIT프로젝트
# 51       HTML5_html
# 52         웹_기타(본부)
# 53          ONL_OMM
# 54         ONL_JAVA
# 55         ONL_DBIO
# 56         채널화면_scn
# 57         채널화면_trn
# 58             배치코드
# 59          채널화면_js
# 60        BAT_Shell
# 61         BAT_Bean
# 62           BAT_배치
# 63         ONL_Bean
# 64         BAT_DBIO
# 65          BAT_OMM
# 66         BAT_JAVA
# 67  ONL_JAVA Module
# 68            웹_C관련
# 69           CONFIG
# 70       웹_xadl(소스)
#
# [71 rows x 1 columns]

# %% [markdown]
# 기술 스택을 파악하기에는 프로그램 종류에 대한 정보가 조금은 부족한 것 같다
#
# 각 프로그램 종류에 따라 어떤 언어나 툴을 사용하는지 파악할 수 있다면 좀 더 다양성을 줄이고 포괄적으로 데이터를 볼 수 있을 듯 하다
#
# 언어/툴/종류에 따라..
#
# **몇가지 알아낸것**
# 1. 신자금세탁방지(AP) 프로그램종류 BAT_ : 배치성 코드
# 2. 신자금세탁방지(AP) 프로그램종류 ONL_ : 서비스 코드
# 3. 금융개발부 DBIO / DBIO MAP : 프로프레임3.0 // 글로개발부 DBI / DBIO MAP : 프로프레임4.0
# >  금융개발부는 프로프레임3.0 사용 <-> 글로벌개발부은 프로프레임4.0 사용
# 4. 금융개발부 IO포맷 / 화면매핑 : iDev@BuildLink
# 5. 금융개발부 화면 : iDev@Tool
# 6. ICT운영부 클라우드 : 내부 gitlab 를 사용하여 프로젝트 관리 > 형상관리에서 끌어다가 GIT프로젝트로 표현

# %%
def add_class(row):
    program = row['프로그램종류']
    if program == '.net(dll)':
        return "VB"
    elif program == '2PC배치':
        return "C"
    elif program == 'BAT_Bean':
        return "JAVA"
    elif program == 'BAT_DBIO':
        return "JAVA"
    elif program == 'BAT_JAVA':
        return "JAVA"
    elif program == 'BAT_OMM':
        return "JAVA"
    elif program == 'BAT_Shell':
        return "JAVA"
    elif program == 'BAT_배치':
        return "JAVA"
    elif program == 'CONFIG':
        return "Shell"
    elif program == 'CTL':
        return "JAVA"
    elif program == 'DBIO':
        return "프로프레임"
    elif program == 'DBIO MAP':
        return "프로프레임"
    elif program == 'FLEX(.mxml)':
        return "FLEX"        
    elif program == 'FLEX(.swf)':
        return "FLEX"        
    elif program == 'FLEX(/bin 파일)':
        return "FLEX"
    elif program == 'FLEX(/src 파일)':
        return "FLEX"
    elif program == 'GIT프로젝트':
        return "Cloud"
    elif program == 'HTML':
        return "HTML "
    elif program == 'HTML5_html':
        return "HTML "
    elif program == 'HTML5_xml':
        return "HTML "
    elif program == 'HTML5_스크립트':
        return "HTML "
    elif program == 'HTML5_이미지':
        return "HTML "
    elif program == 'Header FILE':
        return "HEADER"
    elif program == 'IO포맷':
        return "iDev@BuildLink"
    elif program == 'IO포맷 ALL':
        return "iDev@BuildLink"
    elif program == 'Image':
        return "기타"
    elif program == 'Java':
        return "JAVA"
    elif program == 'MODULE':
        return "C"
    elif program == 'ONL_Bean':
        return "JAVA"
    elif program == 'ONL_DBIO':
        return "JAVA"
    elif program == 'ONL_JAVA':
        return "JAVA"
    elif program == 'ONL_JAVA Module':
        return "JAVA"
    elif program == 'ONL_OMM':
        return "JAVA"
    elif program == 'PACKAGE':
        return "기타"
    elif program == 'SCRIPT':
        return "Shell"
    elif program == 'SHELL':
        return "Shell"
    elif program == 'SQL':
        return "SQL"
    elif program == 'XML':
        return "xml"
    elif program == '거래코드':
        return "C"
    elif program == '공통모듈':
        return "C"
    elif program == '배치':
        return "C"        
    elif program == '배치(*.pc)':
        return "C"
    elif program == '배치코드':
        return "C"
    elif program == '상주배치':
        return "C"
    elif program == '스크립트(긴급)':
        return "Shell"
    elif program == '스크립트(일반)':
        return "Shell"
    elif program == '실행모듈(서버)':
        return "Server"
    elif program == '연동코드':
        return "C"
    elif program == '온라인서비스':
        return "C"
    elif program.startswith('웹'):
        return "Web"
    elif program == '채널매핑룰':
        return "iDev@BuildLink"
    elif program == '채널매핑룰.chl':
        return "iDev@BuildLink"
    elif program == '채널매핑룰.rule':
        return "iDev@BuildLink"
    elif program == '채널화면_MAP':
        return "iDev@Tool"
    elif program == '채널화면_js':
        return "iDev@Tool"
    elif program == '채널화면_mrd':
        return "iDev@Tool"
    elif program == '채널화면_scn':
        return "iDev@Tool"
    elif program == '채널화면_trn':
        return "iDev@Tool"
    elif program == '채널화면_txt':
        return "iDev@Tool"
    elif program == '프로프레임소스(.c)':
        return "C"
    elif program == '화면_VB':
        return "VB"
    elif program == '후행성배치':
        return "C"

# %%
df['A'] = df.apply(lambda x: add_class(x), axis=1)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['A_COUNT'] = df.groupby(['A', '프로그램종류'])[['JIKWON_NO']].transform('count')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['B_COUNT'] = df.groupby(['시스템유형', '업무그룹', '업무'])[['JIKWON_NO']].transform('count')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head(2)
# Out:
#    JIKWON_NO  JEOM_NO  JIKGUN  JIKGEUB  JIKWHI  JIKWHI2  JUJKMU_C  \
# 0   20101491       63   20004        5   20164        3   11609.0
# 1   20101491       63   20004        5   20164        3   11609.0
#
#    JUJKMU_RATE  BUJKMU_C  BUJKMU_RATE   ...    프로그램종류        프로그램명  \
# 0        100.0       NaN          0.0   ...    온라인서비스  sfis2100d.c
# 1        100.0       NaN          0.0   ...    온라인서비스  sfis7100a.c
#
#            프로젝트번호        요청일자 요청구분            요청번호               프로그램경로  A  \
# 0  P2021-00342-01  2021-01-20   수정  2021-04-002421  /nbsdev/fib/fis/src  C
# 1  P2021-00342-01  2021-01-20   수정  2021-04-002421  /nbsdev/fib/fis/src  C
#
#   A_COUNT B_COUNT
# 0   15617     531
# 1   15617     531
#
# [2 rows x 26 columns]

# %% [markdown]
# # Export Data

# %%
data_for_dash2 = pd.merge(left=df[['JIKWON_NO', '시스템유형', '업무그룹', '업무', '프로그램종류', '프로그램명', 'A', 'A_COUNT', 'B_COUNT']],
                         right=df_jikwon[['JIKWON_NO', 'NAME']],
                         how='left', left_on='JIKWON_NO', right_on='JIKWON_NO')

# %%
data_for_dash2
# Out:
#         JIKWON_NO 시스템유형                업무그룹     업무       프로그램종류  \
# 0        20101491    코어    External Channel    펌뱅킹       온라인서비스
# 1        20101491    코어    External Channel    펌뱅킹       온라인서비스
# 2        20101491    코어    External Channel    펌뱅킹     채널화면_txt
# 3        20101491    코어  External Interface   가상계좌       온라인서비스
# 4        20101491    코어             단위I/F공통   전자금융       온라인서비스
# 5        20101491    코어  External Interface   가상계좌     채널화면_txt
# 6        20101491    코어  External Interface   가상계좌           배치
# 7        20101491    코어    External Channel    펌뱅킹     채널화면_txt
# 8        20101491    코어  External Interface   가상계좌     채널화면_txt
# 9        20101491    코어  External Interface   가상계좌     채널화면_txt
# 10       20101491    코어    External Channel    펌뱅킹         거래코드
# 11       20101491    코어    External Channel    펌뱅킹     채널화면_MAP
# 12       20101491    코어    External Channel   전자금융     IO포맷 ALL
# 13       20101491    코어  External Interface   가상계좌         거래코드
# 14       20101491    코어  External Interface   가상계좌     채널화면_txt
# 15       20101491    코어  External Interface   가상계좌     채널화면_MAP
# 16       20101491    코어    External Channel    펌뱅킹       온라인서비스
# 17       20101491    코어    External Channel   전자금융     채널화면_MAP
# 18       20101491    코어  External Interface   가상계좌     채널화면_txt
# 19       20101491    코어    External Channel   전자금융     DBIO MAP
# 20       20101491    코어    External Channel    펌뱅킹         거래코드
# 21       20101491    코어  External Interface   가상계좌     DBIO MAP
# 22       20101491    코어    External Channel    펌뱅킹           배치
# 23       20101491    코어  External Interface   가상계좌     채널화면_MAP
# 24       20101491    코어  External Interface   가상계좌     채널화면_MAP
# 25       20101491    코어    External Channel    펌뱅킹         거래코드
# 26       20101491    코어    External Channel    펌뱅킹     채널화면_MAP
# 27       20101491    코어  External Interface   가상계좌     채널화면_MAP
# 28       20101491    코어    External Channel    펌뱅킹         거래코드
# 29       20101491    코어  External Interface   가상계좌       온라인서비스
# ...           ...   ...                 ...    ...          ...
# 355398   18101798    코어                  수신   수익증권         DBIO
# 355399   18101798    코어                  수신  수신 공통         거래코드
# 355400   18101798    코어                  수신   수신관리     DBIO MAP
# 355401   18101798    코어                  수신   수익증권     DBIO MAP
# 355402   18101798    코어                  수신   수익증권       온라인서비스
# 355403   18101798    코어                  수신   수익증권       온라인서비스
# 355404   18101798    코어                  수신  수신 공통        채널매핑룰
# 355405   18101798    코어                  수신   수익증권       온라인서비스
# 355406   18101798    코어                  수신   수익증권       온라인서비스
# 355407   18101798    코어                  수신   수익증권  Header FILE
# 355408   18101798    코어                  수신   수익증권         DBIO
# 355409   18101798    코어                  수신  수신 공통         공통모듈
# 355410   18101798    코어                  수신   수익증권     채널화면_MAP
# 355411   18101798    코어                  수신   수익증권     채널화면_txt
# 355412   18101798    코어                  수신   수익증권           배치
# 355413   18101798    코어                  수신   수익증권       온라인서비스
# 355414   18101798    코어                  수신   수익증권     DBIO MAP
# 355415   18101798    코어                  수신   수익증권     DBIO MAP
# 355416   18101798    코어                  수신   수익증권        SHELL
# 355417   18101798    코어                  수신   수익증권         DBIO
# 355418   18101798    코어                  수신   수익증권     DBIO MAP
# 355419   18101798    코어                  수신   수익증권         DBIO
# 355420   18101798    코어                  수신   수익증권           배치
# 355421   18101798    코어                  수신   수익증권         공통모듈
# 355422   18101798    코어                  수신   수익증권         DBIO
# 355423   18101798    코어                  수신   수익증권         DBIO
# 355424   18101798    코어                  수신  수신 공통       온라인서비스
# 355425   18101798    코어                  수신   수익증권     DBIO MAP
# 355426   18101798    코어                  수신   수익증권     채널화면_mrd
# 355427   18101798    코어                  수신   수익증권       온라인서비스
#
#                                프로그램명               A  A_COUNT  B_COUNT  \
# 0                        sfis2100d.c               C    15617      531
# 1                        sfis7100a.c               C    15617      531
# 2                     5639000000.txt       iDev@Tool     5246      531
# 3                        svas1102c.c               C    15617       72
# 4                        selb0002a.c               C    15617      160
# 5                     6004230000.txt       iDev@Tool     5246       72
# 6                 bvas_vrfy_divrst.c               C     5398       72
# 7                     5631050000.txt       iDev@Tool     5246      531
# 8                     6006170000.txt       iDev@Tool     5246       72
# 9                     6004060000.txt       iDev@Tool     5246       72
# 10                 S001_SFIS2101H001               C     6356      531
# 11                    5639000000.MAP       iDev@Tool     5247      531
# 12                     sfis9090a_out  iDev@BuildLink     7701       19
# 13                 S001_SVAS0615A002               C     6356       72
# 14                    6004120000.txt       iDev@Tool     5246       72
# 15                    6009020000.MAP       iDev@Tool     5247       72
# 16                       sfis3000a.c               C    15617      531
# 17                    5690900000.MAP       iDev@Tool     5247       19
# 18                    6001020000.txt       iDev@Tool     5246       72
# 19                 fis_test_mas_f001           프로프레임    78791       19
# 20                 S001_SFIS9091A001               C     6356      531
# 21                 vas_daip_slv_f102           프로프레임    78791       72
# 22             bfis_aptrx_jrn_load.c               C     5398      531
# 23                    6004230000.MAP       iDev@Tool     5247       72
# 24                    6004130000.MAP       iDev@Tool     5247       72
# 25                 S001_SFIS9056A001               C     6356      531
# 26                    5621000000.MAP       iDev@Tool     5247      531
# 27                    6001020002.MAP       iDev@Tool     5247       72
# 28                 S001_SFIS9091A002               C     6356      531
# 29                       svas0422a.c               C    15617       72
# ...                              ...             ...      ...      ...
# 355398     libpdb_sdm_pbyeyak_slv.so           프로프레임    16864      842
# 355399             S001_SSDM0322B001               C     6356     1338
# 355400           sdm_taiche_slv_d010           프로프레임    78791      629
# 355401         sdm_sbc_itasbprc_d001           프로프레임    78791      842
# 355402                   ssbc0001a.c               C    15617      842
# 355403                   ssbc0001a.c               C    15617      842
# 355404  A0_0000030003_SCUM7022T001_I  iDev@BuildLink     9447     1338
# 355405                   ssbc0001a.c               C    15617      842
# 355406                   ssbc0001a.c               C    15617      842
# 355407            msdm_chek_gusoks.h          HEADER     4237      842
# 355408      libpdb_sdm_smcall_mas.so           프로프레임    16864      842
# 355409            msdm_comp_jilgwn.c               C     3546     1338
# 355410                0010000000.MAP       iDev@Tool     5247      842
# 355411                0000800000.txt       iDev@Tool     5246      842
# 355412          bsdm_sbc_yetakija2.c               C     5398      842
# 355413                   ssbc0001b.c               C    15617      842
# 355414            sdm_sbc_varcc_u000           프로프레임    78791      842
# 355415         sdm_sbc_itasbprc_d000           프로프레임    78791      842
# 355416           bsdm_ccex_suik24.sh           Shell    29600      842
# 355417       libpdb_sdm_sbc_varcc.so           프로프레임    16864      842
# 355418            sdm_sbc_varcc_i000           프로프레임    78791      842
# 355419       libpdb_sdm_jkrip_mas.so           프로프레임    16864      842
# 355420            bsdm_rept_fund27.c               C     5398      842
# 355421            msdm_johe_bckj01.c               C     3546      842
# 355422    libpdb_sdm_sbc_itasbprc.so           프로프레임    16864      842
# 355423    libpdb_sdm_sbc_realvalt.so           프로프레임    16864      842
# 355424                   ssdm0020b.c               C    15617     1338
# 355425         sdm_bosukjbb_slv_s005           프로프레임    78791      842
# 355426                0003010542.mrd       iDev@Tool     1266      842
# 355427            msdm_chng_budoji.c               C    15617      842
#
#                      NAME
# 0       신범철
# 1       신범철
# 2       신범철
# 3       신범철
# 4       신범철
# 5       신범철
# 6       신범철
# 7       신범철
# 8       신범철
# 9       신범철
# 10      신범철
# 11      신범철
# 12      신범철
# 13      신범철
# 14      신범철
# 15      신범철
# 16      신범철
# 17      신범철
# 18      신범철
# 19      신범철
# 20      신범철
# 21      신범철
# 22      신범철
# 23      신범철
# 24      신범철
# 25      신범철
# 26      신범철
# 27      신범철
# 28      신범철
# 29      신범철
# ...                   ...
# 355398  민남규
# 355399  민남규
# 355400  민남규
# 355401  민남규
# 355402  민남규
# 355403  민남규
# 355404  민남규
# 355405  민남규
# 355406  민남규
# 355407  민남규
# 355408  민남규
# 355409  민남규
# 355410  민남규
# 355411  민남규
# 355412  민남규
# 355413  민남규
# 355414  민남규
# 355415  민남규
# 355416  민남규
# 355417  민남규
# 355418  민남규
# 355419  민남규
# 355420  민남규
# 355421  민남규
# 355422  민남규
# 355423  민남규
# 355424  민남규
# 355425  민남규
# 355426  민남규
# 355427  민남규
#
# [355428 rows x 10 columns]

# %%
data_for_dash2.to_csv(os.path.join(root, 'data_for_dash2.csv'), na_rep='NaN')
